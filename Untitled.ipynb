# %%
import pandas as pd

# %%
df=pd.read_table('data/hmr/mye-lym',header=None)
df.shape
# Out:
# (15938, 6)

# %%
df['d']=df[2]-df[1]

# %%
df.sort_values('d').tail(20)
# Out:
#            0          1          2          3    4  5      d
# 12424  chr17   22146402   22150110  HYPO41915   10  +   3708
# 4425    chr5  170311692  170315409  HYPO15240   18  +   3717
# 905     chr1  161214029  161217753   HYPO3622   28  +   3724
# 14763  chr21   15436427   15440250  HYPO50427   12  +   3823
# 7821   chr10   38961806   38965711  HYPO26538   17  +   3905
# 622     chr1   66372392   66376323   HYPO2376   25  +   3931
# 846     chr1  155005115  155009172   HYPO3366   46  +   4057
# 9383   chr12   14980907   14984980  HYPO31802   15  +   4073
# 773     chr1  125096191  125100266   HYPO2988   11  +   4075
# 6967    chr9   64111363   64115440  HYPO23891   12  +   4077
# 13972  chr19   41755471   41759614  HYPO47466   33  +   4143
# 14601  chr20   58839106   58843318  HYPO49923  240  +   4212
# 14735  chr21    8872747    8877249  HYPO50377   14  +   4502
# 3625    chr4  100514806  100519390  HYPO12558   33  +   4584
# ...

# %%
merge=pd.read_table('data/merge/merge',index_col=0)

# %%
m=pd.read_table('data/stat/cd4',header=None)
m.shape
# Out:
# (62385, 6)

# %%
m.sort_values(4).dropna()
# Out:
#            0          1          2          3         4  5
# 34019   chr2  160939364  160939413   HYPO8494  0.000000  +
# 14816  chr13   16797036   16797098  HYPO38429  0.000000  +
# 32997   chr2   95645795   95646170   HYPO7472  0.000000  +
# 14817  chr13   16872357   16872607  HYPO38430  0.000000  +
# 14828  chr13   18014876   18015174  HYPO38441  0.000000  +
# ...      ...        ...        ...        ...       ... ..
# 46276   chr5   46899534   46900610  HYPO15754  0.553506  +
# 46271   chr5   46770696   46772244  HYPO15749  0.560000  +
# 23998  chr17   25062124   25063063  HYPO47611  0.564960  +
# 3411    chr1  143521869  143523312   HYPO3411  0.565217  +
# 46263   chr5   46700576   46701401  HYPO15741  0.632911  +
#
# [59902 rows x 6 columns]

# %%
df.sort_values(4).tail(50)
# Out:
#            0         1         2          3   4  5
# 40388  chr22  50184937  50187025  HYPO59852 NaN  +
# 40389  chr22  50187277  50187349  HYPO59853 NaN  +
# 40390  chr22  50189953  50191893  HYPO59854 NaN  +
# 40391  chr22  50192356  50192650  HYPO59855 NaN  +
# 40392  chr22  50192960  50193166  HYPO59856 NaN  +
# 40393  chr22  50199887  50202104  HYPO59857 NaN  +
# 40394  chr22  50209997  50210148  HYPO59858 NaN  +
# 40395  chr22  50241102  50241510  HYPO59859 NaN  +
# 40396  chr22  50243682  50245731  HYPO59860 NaN  +
# 40397  chr22  50250577  50251951  HYPO59861 NaN  +
# 40398  chr22  50252125  50252417  HYPO59862 NaN  +
# 40399  chr22  50260671  50262326  HYPO59863 NaN  +
# 40400  chr22  50262697  50262931  HYPO59864 NaN  +
# 40401  chr22  50267642  50268106  HYPO59865 NaN  +
# 40402  chr22  50269561  50272159  HYPO59866 NaN  +
# 40403  chr22  50274433  50274576  HYPO59867 NaN  +
# 40404  chr22  50292638  50294436  HYPO59868 NaN  +
# ...

# %%
mono=pd.read_table('data/hmr/cd4.hmr',header=None)

# %%
mono.head(1000)
# Out:
#         0         1         2        3    4  5
# 0    chr1     28166     29489    HYPO0   63  +
# 1    chr1     87700     88386    HYPO1    7  +
# 2    chr1    322115    322490    HYPO2   10  +
# 3    chr1    327121    327567    HYPO3   19  +
# 4    chr1    355824    356069    HYPO4    5  +
# ..    ...       ...       ...      ...  ... ..
# 995  chr1  17678206  17679061  HYPO995    8  +
# 996  chr1  17743699  17744851  HYPO996   20  +
# 997  chr1  17759407  17765686  HYPO997  282  +
# 998  chr1  17799767  17800017  HYPO998    5  +
# 999  chr1  17822810  17823602  HYPO999   12  +
#
# [1000 rows x 6 columns]

# %%
mono[mono[3]=='HYPO46719']
# Out:
#            0         1         2          3    4  5
# 46719  chr15  65427923  65477762  HYPO46719  688  +

# %%
pd.read_table('data/meth/hm',header=None).sort_values(4)
# Out:
#          0         1         2         3    4  5
# 2255  chr1  54055395  54055900  HYPO2255    5  +
# 2537  chr1  79088592  79089282  HYPO2537    5  +
# 175   chr1   2222719   2222896   HYPO175    5  +
# 1610  chr1  32732050  32732205  HYPO1610    5  +
# 1623  chr1  32869853  32870068  HYPO1623    5  +
# ...    ...       ...       ...       ...  ... ..
# 266   chr1   3024749   3038744   HYPO266  471  +
# 2497  chr1  75591510  75610780  HYPO2497  482  +
# 2379  chr1  63782884  63795474  HYPO2379  703  +
# 966   chr1  18949577  18972911   HYPO966  806  +
# 2194  chr1  50881424  50903115  HYPO2194  875  +
#
# [2559 rows x 6 columns]
